# %% [markdown]
# ## March Coding Challenges

# %%
#clean and analyse the data
#Author: Bralyne Vanessa Matoukam
import pandas as pd#import necessary library
import seaborn as sns#import necessary library
df = pd.read_csv('movie_dataset.csv')#read the data

pd.set_option('display.max_rows',None)#display all the rows

# remove special character
df.columns = df.columns.str.replace(' ', '')#remove the space in columns
df['Actors'] =df['Actors'].str.replace(' ', '')#remove the space in actors names
df['Actors'] =df['Actors'].str.replace(',', ' ')#replace the comma by space in Actors column
df['Genre'] =df['Genre'].str.replace(',', ' ')#replace the comma by space in Genre column

#drop a column

df.drop(['Rank'],inplace=True,axis=1)#remove Rank column because panda will generate an index for us

#Replace Empty Values – Using fillna
x = df["Metascore"].mean()#calculate the mean of the data in Metascore

df["Metascore"].fillna(x, inplace = True)#fill the missing values

x = df["Revenue(Millions)"].mean()#calculate the mean of the data in Revenue(Millions)

df["Revenue(Millions)"].fillna(x, inplace = True)#fill the missing value

df
# Out:
#                                                  Title  \
# 0                              Guardians of the Galaxy
# 1                                           Prometheus
# 2                                                Split
# 3                                                 Sing
# 4                                        Suicide Squad
# 5                                       The Great Wall
# 6                                           La La Land
# 7                                             Mindhorn
# 8                                   The Lost City of Z
# 9                                           Passengers
# 10             Fantastic Beasts and Where to Find Them
# 11                                      Hidden Figures
# 12                                           Rogue One
# 13                                               Moana
# 14                                            Colossal
# 15                             The Secret Life of Pets
# ...

# %%
#What is the highest rated movie in the dataset?
df[['Rating']].idxmax()#looking for the index of the highest rated movie
# Out:
# Rating    54
# dtype: int64

# %%
#What is the highest rated movie in the dataset?
df._get_value(54, 'Title')#from the previous code, the index of the highest rated movie is 54
#this code provide the title of the movie at index 54
# Out:
# 'The Dark Knight'

# %%
#What is the average revenue of all movies in the dataset? 
df['Revenue(Millions)'].mean()#getting the mean of revenue
# Out:
# 82.9563761467888

# %%
#What is the average revenue of movies from 2015 to 2017 in the dataset?
for x in df.index:
    if df.loc[x, "Year"]not in range(2015,2018):
        df.drop(x, inplace = True)
df['Revenue(Millions)'].mean()
# Out:
# 68.0640232819806

# %%
#How many movies were released in the year 2016?
for x in df.index:
    if df.loc[x, "Year"]not in range(2016,2017):
        df.drop(x, inplace = True)   
len(df.index)
# Out:
# 297

# %%
#How many movies were directed by Christopher Nolan?

#we have to run the data anytime we are updating the data

#######################################
df = pd.read_csv('movie_dataset.csv')#read the data

pd.set_option('display.max_rows',None)#display all the rows

# remove special character
df.columns = df.columns.str.replace(' ', '')#remove the space in columns
df['Actors'] =df['Actors'].str.replace(' ', '')#remove the space in actors names
df['Actors'] =df['Actors'].str.replace(',', ' ')#replace the comma by space in Actors column
df['Genre'] =df['Genre'].str.replace(',', ' ')#replace the comma by space in Genre column

#drop a column

df.drop(['Rank'],inplace=True,axis=1)#remove Rank column because panda will generate an index for us

#Replace Empty Values – Using fillna
x = df["Metascore"].mean()#calculate the mean of the data in Metascore

df["Metascore"].fillna(x, inplace = True)#fill the missing values

x = df["Revenue(Millions)"].mean()#calculate the mean of the data in Revenue(Millions)

df["Revenue(Millions)"].fillna(x, inplace = True)#fill the missing value

#########################################################################
#the answer starts here
for x in df.index:
    if 'Christopher Nolan' not in (df.loc[x, "Director"]):
        df.drop(x, inplace = True)
len(df.index)
# Out:
# 5

# %%
#How many movies in the dataset have a rating of at least 8.0?

#we have to run the data anytime we are updating the data

#######################################
df = pd.read_csv('movie_dataset.csv')#read the data

pd.set_option('display.max_rows',None)#display all the rows

# remove special character
df.columns = df.columns.str.replace(' ', '')#remove the space in columns
df['Actors'] =df['Actors'].str.replace(' ', '')#remove the space in actors names
df['Actors'] =df['Actors'].str.replace(',', ' ')#replace the comma by space in Actors column
df['Genre'] =df['Genre'].str.replace(',', ' ')#replace the comma by space in Genre column

#drop a column

df.drop(['Rank'],inplace=True,axis=1)#remove Rank column because panda will generate an index for us

#Replace Empty Values – Using fillna
x = df["Metascore"].mean()#calculate the mean of the data in Metascore

df["Metascore"].fillna(x, inplace = True)#fill the missing values

x = df["Revenue(Millions)"].mean()#calculate the mean of the data in Revenue(Millions)

df["Revenue(Millions)"].fillna(x, inplace = True)#fill the missing value

#########################################################################


#the answer starts here

for x in df.index:
    if df.loc[x, "Rating"]<8.0:
        df.drop(x, inplace = True)
len(df.index)
# Out:
# 78

# %%
#What is the median rating of movies directed by Christopher Nolan?

#we have to run the data anytime we are updating the data

#######################################
df = pd.read_csv('movie_dataset.csv')#read the data

pd.set_option('display.max_rows',None)#display all the rows

# remove special character
df.columns = df.columns.str.replace(' ', '')#remove the space in columns
df['Actors'] =df['Actors'].str.replace(' ', '')#remove the space in actors names
df['Actors'] =df['Actors'].str.replace(',', ' ')#replace the comma by space in Actors column
df['Genre'] =df['Genre'].str.replace(',', ' ')#replace the comma by space in Genre column

#drop a column

df.drop(['Rank'],inplace=True,axis=1)#remove Rank column because panda will generate an index for us

#Replace Empty Values – Using fillna
x = df["Metascore"].mean()#calculate the mean of the data in Metascore

df["Metascore"].fillna(x, inplace = True)#fill the missing values

x = df["Revenue(Millions)"].mean()#calculate the mean of the data in Revenue(Millions)

df["Revenue(Millions)"].fillna(x, inplace = True)#fill the missing value

#########################################################################


#the answer starts here
for x in df.index:
    if 'Christopher Nolan' not in (df.loc[x, "Director"]):
        df.drop(x, inplace = True)
df['Rating'].median()
# Out:
# 8.6

# %%
#Find the year with the highest average rating?

#we have to run the data anytime we are updating the data

#######################################
df = pd.read_csv('movie_dataset.csv')#read the data

pd.set_option('display.max_rows',None)#display all the rows

# remove special character
df.columns = df.columns.str.replace(' ', '')#remove the space in columns
df['Actors'] =df['Actors'].str.replace(' ', '')#remove the space in actors names
df['Actors'] =df['Actors'].str.replace(',', ' ')#replace the comma by space in Actors column
df['Genre'] =df['Genre'].str.replace(',', ' ')#replace the comma by space in Genre column

#drop a column

df.drop(['Rank'],inplace=True,axis=1)#remove Rank column because panda will generate an index for us

#Replace Empty Values – Using fillna
x = df["Metascore"].mean()#calculate the mean of the data in Metascore

df["Metascore"].fillna(x, inplace = True)#fill the missing values

x = df["Revenue(Millions)"].mean()#calculate the mean of the data in Revenue(Millions)

df["Revenue(Millions)"].fillna(x, inplace = True)#fill the missing value

#########################################################################


h=[]
for i in range(2006,2017):
    df = pd.read_csv('movie_dataset.csv')
    for x in df.index:
        if df.loc[x, "Year"]not in range(i,i+1):
            df.drop(x, inplace = True)
    h.append(df['Rating'].mean())
(h.index((max(h)))+2006)
# Out:
# 2007

# %%
#What is the percentage increase in number of movies made between 2006 and 2016?

#we have to run the data anytime we are updating the data

#######################################
df = pd.read_csv('movie_dataset.csv')#read the data

pd.set_option('display.max_rows',None)#display all the rows

# remove special character
df.columns = df.columns.str.replace(' ', '')#remove the space in columns
df['Actors'] =df['Actors'].str.replace(' ', '')#remove the space in actors names
df['Actors'] =df['Actors'].str.replace(',', ' ')#replace the comma by space in Actors column
df['Genre'] =df['Genre'].str.replace(',', ' ')#replace the comma by space in Genre column

#drop a column

df.drop(['Rank'],inplace=True,axis=1)#remove Rank column because panda will generate an index for us

#Replace Empty Values – Using fillna
x = df["Metascore"].mean()#calculate the mean of the data in Metascore

df["Metascore"].fillna(x, inplace = True)#fill the missing values

x = df["Revenue(Millions)"].mean()#calculate the mean of the data in Revenue(Millions)

df["Revenue(Millions)"].fillna(x, inplace = True)#fill the missing value

#########################################################################

#The answer starts here

for x in df.index:
    if df.loc[x, "Year"]not in range(2006,2007):#we want the number of movies made in 2006
        df.drop(x, inplace = True)
T=len(df.index)


#we have to run the data anytime we are updating the data

#######################################
df = pd.read_csv('movie_dataset.csv')#read the data

pd.set_option('display.max_rows',None)#display all the rows

# remove special character
df.columns = df.columns.str.replace(' ', '')#remove the space in columns
df['Actors'] =df['Actors'].str.replace(' ', '')#remove the space in actors names
df['Actors'] =df['Actors'].str.replace(',', ' ')#replace the comma by space in Actors column
df['Genre'] =df['Genre'].str.replace(',', ' ')#replace the comma by space in Genre column



#drop a column

df.drop(['Rank'],inplace=True,axis=1)#remove Rank column because panda will generate an index for us

#Replace Empty Values – Using fillna
x = df["Metascore"].mean()#calculate the mean of the data in Metascore

df["Metascore"].fillna(x, inplace = True)#fill the missing values

x = df["Revenue(Millions)"].mean()#calculate the mean of the data in Revenue(Millions)

df["Revenue(Millions)"].fillna(x, inplace = True)#fill the missing value

#########################################################################

#The answer continues here
for x in df.index:
    if df.loc[x, "Year"]not in range(2016,2017):#we want the number of movies made in 2016
        df.drop(x, inplace = True)
G=len(df.index)


abs(((T-G)/T)*100)
# Out:
# 575.0

# %%
#Find the most common actor in all the movies?

#we have to run the data anytime we are updating the data

#######################################
df = pd.read_csv('movie_dataset.csv')#read the data

pd.set_option('display.max_rows',None)#display all the rows

# remove special character
df.columns = df.columns.str.replace(' ', '')#remove the space in columns
df['Actors'] =df['Actors'].str.replace(' ', '')#remove the space in actors names
df['Actors'] =df['Actors'].str.replace(',', ' ')#replace the comma by space in Actors column
df['Genre'] =df['Genre'].str.replace(',', ' ')#replace the comma by space in Genre column


#drop a column

df.drop(['Rank'],inplace=True,axis=1)#remove Rank column because panda will generate an index for us

#Replace Empty Values – Using fillna
x = df["Metascore"].mean()#calculate the mean of the data in Metascore

df["Metascore"].fillna(x, inplace = True)#fill the missing values

x = df["Revenue(Millions)"].mean()#calculate the mean of the data in Revenue(Millions)

df["Revenue(Millions)"].fillna(x, inplace = True)#fill the missing value

#####################################################

#The answer starts here
(df['Actors'].str.split().explode().value_counts())#this will count each value and display from
#the highest to the lowest
# Out:
# MarkWahlberg                 15
# HughJackman                  14
# ChristianBale                13
# BradPitt                     13
# ChanningTatum                12
# TomHardy                     12
# AnneHathaway                 12
# JohnnyDepp                   12
# MichaelFassbender            12
# RobertDowneyJr.              12
# ScarlettJohansson            12
# GerardButler                 11
# JenniferLawrence             11
# JakeGyllenhaal               11
# CateBlanchett                11
# SethRogen                    11
# AnnaKendrick                 11
# BradleyCooper                11
# ChloëGraceMoretz             11
# ShiaLaBeouf                  11
# EmmaStone                    10
# ChrisHemsworth               10
# LeonardoDiCaprio             10
# JoshBrolin                   10
# CharlizeTheron               10
# WillSmith                    10
# RyanGosling                  10
# DwayneJohnson                10
# MatthewMcConaughey           10
# ...

# %%
#How many unique genres are there in the dataset?

#we have to run the data anytime we are updating the data

#######################################
df = pd.read_csv('movie_dataset.csv')#read the data

pd.set_option('display.max_rows',None)#display all the rows

# remove special character
df.columns = df.columns.str.replace(' ', '')#remove the space in columns
df['Actors'] =df['Actors'].str.replace(' ', '')#remove the space in actors names
df['Actors'] =df['Actors'].str.replace(',', ' ')#replace the comma by space in Actors column
df['Genre'] =df['Genre'].str.replace(',', ' ')#replace the comma by space in Genre column


#drop a column

df.drop(['Rank'],inplace=True,axis=1)#remove Rank column because panda will generate an index for us

#Replace Empty Values – Using fillna
x = df["Metascore"].mean()#calculate the mean of the data in Metascore

df["Metascore"].fillna(x, inplace = True)#fill the missing values

x = df["Revenue(Millions)"].mean()#calculate the mean of the data in Revenue(Millions)

df["Revenue(Millions)"].fillna(x, inplace = True)#fill the missing value

#####################################################

#The answer starts here
len(df['Genre'].str.split().explode().value_counts())#this will count each value and display the lenght 
#of the serie
# Out:
# 20

# %%
df.corr()
# Out:
#                        Year  Runtime(Minutes)    Rating     Votes  \
# Year               1.000000         -0.164900 -0.211219 -0.411904
# Runtime(Minutes)  -0.164900          1.000000  0.392214  0.407062
# Rating            -0.211219          0.392214  1.000000  0.511537
# Votes             -0.411904          0.407062  0.511537  1.000000
# Revenue(Millions) -0.117562          0.247834  0.189527  0.607941
# Metascore         -0.076077          0.202239  0.604723  0.318116
#
#                    Revenue(Millions)  Metascore
# Year                       -0.117562  -0.076077
# Runtime(Minutes)            0.247834   0.202239
# Rating                      0.189527   0.604723
# Votes                       0.607941   0.318116
# Revenue(Millions)           1.000000   0.132304
# Metascore                   0.132304   1.000000

# %%
df.describe()
# Out:
#               Year  Runtime(Minutes)       Rating         Votes  \
# count  1000.000000       1000.000000  1000.000000  1.000000e+03
# mean   2012.783000        113.172000     6.723200  1.698083e+05
# std       3.205962         18.810908     0.945429  1.887626e+05
# min    2006.000000         66.000000     1.900000  6.100000e+01
# 25%    2010.000000        100.000000     6.200000  3.630900e+04
# 50%    2014.000000        111.000000     6.800000  1.107990e+05
# 75%    2016.000000        123.000000     7.400000  2.399098e+05
# max    2016.000000        191.000000     9.000000  1.791916e+06
#
#        Revenue(Millions)    Metascore
# count        1000.000000  1000.000000
# mean           82.956376    58.985043
# std            96.412043    16.634858
# min             0.000000    11.000000
# 25%            17.442500    47.750000
# 50%            60.375000    58.985043
# 75%            99.177500    71.000000
# max           936.630000   100.000000

# %%
sns.heatmap(df.corr(), annot = True, vmin = -1, vmax = 1)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12, 7))
sns.heatmap(data.drop(['Kilometers_Driven','Price'],axis=1).corr(), annot = True, vmin = -1, vmax = 1)
plt.show()

# %%
df.describe()
# Out:
#               Year  Runtime(Minutes)       Rating         Votes  \
# count  1000.000000       1000.000000  1000.000000  1.000000e+03
# mean   2012.783000        113.172000     6.723200  1.698083e+05
# std       3.205962         18.810908     0.945429  1.887626e+05
# min    2006.000000         66.000000     1.900000  6.100000e+01
# 25%    2010.000000        100.000000     6.200000  3.630900e+04
# 50%    2014.000000        111.000000     6.800000  1.107990e+05
# 75%    2016.000000        123.000000     7.400000  2.399098e+05
# max    2016.000000        191.000000     9.000000  1.791916e+06
#
#        Revenue(Millions)    Metascore
# count        1000.000000  1000.000000
# mean           82.956376    58.985043
# std            96.412043    16.634858
# min             0.000000    11.000000
# 25%            17.442500    47.750000
# 50%            60.375000    58.985043
# 75%            99.177500    71.000000
# max           936.630000   100.000000

# %% [markdown]
# Do a correlation of the numerical features, what insights can you deduce? Mention at least 5 insights.
#
# And what advice can you give directors to produce better movies?

# %%
df[['Votes']].idxmin()
# Out:
# Votes    478
# dtype: int64
